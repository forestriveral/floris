# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('/Users/forestriveral/Documents/Projects/WFLO')
print(os.getcwd())
import numpy as np
from farms.Horns import HornsRev1
import utils.ops as ops
# Out:
# /Users/forestriveral/Documents/Projects/WFLO/debug

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Bastankhah",],
#         "wm": ["Jensen",],
        "wsm": ["SS",],
        "tim": [None, "Crespo", "Frandsen", "Larsen", "IEC"],
        "tsm": None,
        "ignore": ["inflow", "wsm"],
    }

theta = [270, 222, 312]
# theta = [270, ]
# sector = [[1], [5], [10], [15]]
sector = [[1],]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"21_04_22/BP/{j}_{k[0]}_BP",dsave=f"21_04_22/BP/{j}_{k[0]}_BP", show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Bastankhah: 42.652 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Bastankhah+Crespo: 41.299 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Bastankhah+Frandsen: 43.591 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Bastankhah+Larsen: 42.033 sec
# ====> calculating Case No.5......
# ...running time of 270+1+Bastankhah+IEC: 42.565 sec
# ** Picture 21_04_22/BP/270_1_BP Save Done !**
#
# ** Data 21_04_22/BP/270_1_BP Save Done !**
#
# ====> calculating Case No.1......
# ...running time of 222+1+Bastankhah: 46.893 sec
# ====> calculating Case No.2......
# ...running time of 222+1+Bastankhah+Crespo: 44.952 sec
# ====> calculating Case No.3......
# ...running time of 222+1+Bastankhah+Frandsen: 47.345 sec
# ====> calculating Case No.4......
# ...running time of 222+1+Bastankhah+Larsen: 45.856 sec
# ====> calculating Case No.5......
# ...

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Jensen", "Bastankhah", "Frandsen",],
#         "wm": ["Jensen",],
        "wsm": ["SS",],
        "tim": [None, ],
        "tsm": None,
        "ignore": ["inflow", "wsm", "tim"],
    }

theta = [270, 222, 312]
# theta = [270, ]
# sector = [[1], [5], [10], [15]]
sector = [[1],]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"21_04_22/BP_WM/{j}_{k[0]}_BW",dsave=f"21_04_22/BP_WM/{j}_{k[0]}_BW", show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Jensen: 0.166 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Bastankhah: 43.205 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Frandsen: 0.172 sec
# ** Picture 21_04_22/BP_WM/270_1_BW Save Done !**
#
# ** Data 21_04_22/BP_WM/270_1_BW Save Done !**
#
# ====> calculating Case No.1......
# ...running time of 222+1+Jensen: 0.128 sec
# ====> calculating Case No.2......
# ...running time of 222+1+Bastankhah: 43.246 sec
# ====> calculating Case No.3......
# ...running time of 222+1+Frandsen: 0.139 sec
# ** Picture 21_04_22/BP_WM/222_1_BW Save Done !**
#
# ** Data 21_04_22/BP_WM/222_1_BW Save Done !**
#
# ====> calculating Case No.1......
# ...running time of 312+1+Jensen: 0.125 sec
# ====> calculating Case No.2......
# ...running time of 312+1+Bastankhah: 45.382 sec
# ====> calculating Case No.3......
# ...running time of 312+1+Frandsen: 0.18 sec
# ...

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Jensen",],
        "wsm": ["SS",],
        "tim": [None, "Crespo", "Frandsen", "Larsen", "IEC"],
        "tsm": None,
        "ignore": ["inflow", "wsm"],
    }

theta = [270, 222, 312]
sector = [[1], [5], [10], [15]]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"20_10_02/2/{j}_{k[0]}_J", dsave=None, show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Jensen: 0.148 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Jensen+Crespo: 0.192 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Jensen+Frandsen: 0.166 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Jensen+Larsen: 0.209 sec
# ====> calculating Case No.5......
# ...running time of 270+1+Jensen+IEC: 0.162 sec
# Index(['270+1+Jensen', '270+1+Jensen+Crespo', '270+1+Jensen+Frandsen',
#        '270+1+Jensen+Larsen', '270+1+Jensen+IEC'],
#       dtype='object')
# ** Picture 20_10_02/2/270_1_J Save Done !**
#
# ====> calculating Case No.1......
# ...running time of 270+5+Jensen: 0.522 sec
# ====> calculating Case No.2......
# ...running time of 270+5+Jensen+Crespo: 0.69 sec
# ====> calculating Case No.3......
# ...running time of 270+5+Jensen+Frandsen: 0.644 sec
# ====> calculating Case No.4......
# ...running time of 270+5+Jensen+Larsen: 0.696 sec
# ...

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Frandsen",],
        "wsm": ["SS",],
        "tim": [None, "Crespo", "Frandsen", "Larsen", "IEC"],
        "tsm": None,
        "ignore": ["inflow", "wsm"],
    }

theta = [270, 222, 312]
sector = [[1], [5], [10], [15]]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"20_10_02/2/{j}_{k[0]}_F", dsave=None, show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Frandsen: 0.149 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Frandsen+Crespo: 0.177 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Frandsen+Frandsen: 0.166 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Frandsen+Larsen: 0.18 sec
# ====> calculating Case No.5......
# ...running time of 270+1+Frandsen+IEC: 0.158 sec
# ====== Picture 20_10_02/2/270_1_F Save Done !======
#
# ====> calculating Case No.1......
# ...running time of 270+5+Frandsen: 0.51 sec
# ====> calculating Case No.2......
# ...running time of 270+5+Frandsen+Crespo: 0.681 sec
# ====> calculating Case No.3......
# ...running time of 270+5+Frandsen+Frandsen: 0.617 sec
# ====> calculating Case No.4......
# ...running time of 270+5+Frandsen+Larsen: 0.663 sec
# ====> calculating Case No.5......
# ...running time of 270+5+Frandsen+IEC: 0.608 sec
# ====== Picture 20_10_02/2/270_5_F Save Done !======
#
# ...
