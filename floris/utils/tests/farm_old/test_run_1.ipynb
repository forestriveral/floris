# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
root = os.path.dirname(os.getcwd())
sys.path.append(root)

import numpy as np
from utils.evaluation import HornsRev1
import utils.ops as ops
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-749c99fb5645> in <module>
#       8
#       9 import numpy as np
# ---> 10 from utils.evaluation import HornsRev1
#      11 import utils.ops as ops
#
# ModuleNotFoundError: No module named 'utils.evaluation'

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
#         "wm": ["Bastankhah",],
        "wm": ["Jensen",],
        "wsm": ["GS", "LS", "EB", "SS",],
        "tim": ["Frandsen",],
        "tsm": None,
        "ignore": ["inflow", ],
    }

# theta = [270, 222, 312]
theta = [270, ]
# sector = [[1], [5], [10], [15]]
sector = [[1],]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"],
                                      sectors=config["sector"],
#                                       psave=f"21_04_22/BP_WSM/{j}_{k[0]}_BF", 
#                                       dsave=f"21_04_22/BP_WSM/{j}_{k[0]}_BF", 
                                      show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Jensen+GS+Frandsen: 0.589 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Jensen+LS+Frandsen: 0.153 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Jensen+EB+Frandsen: 0.169 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Jensen+SS+Frandsen: 0.158 sec

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Jensen",],
        "wsm": ["GS", "LS", "EB", "SS",],
        "tim": ["Crespo",],
        "tsm": None,
        "ignore": ["inflow", ],
    }

theta = [270, 222, 312]
sector = [[1], [5], [10], [15]]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"20_10_02/3/{j}_{k[0]}_JC", dsave=None, show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Jensen+GS+Crespo: 0.168 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Jensen+LS+Crespo: 0.16 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Jensen+EB+Crespo: 0.172 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Jensen+SS+Crespo: 0.163 sec
# ====== Picture 20_10_02/3/270_1_JC Save Done !======
#
# ====> calculating Case No.1......
# ...running time of 270+5+Jensen+GS+Crespo: 0.605 sec
# ====> calculating Case No.2......
# ...running time of 270+5+Jensen+LS+Crespo: 0.591 sec
# ====> calculating Case No.3......
# ...running time of 270+5+Jensen+EB+Crespo: 0.642 sec
# ====> calculating Case No.4......
# ...running time of 270+5+Jensen+SS+Crespo: 0.638 sec
# ====== Picture 20_10_02/3/270_5_JC Save Done !======
#
# ====> calculating Case No.1......
# ...running time of 270+10+Jensen+GS+Crespo: 1.193 sec
# ====> calculating Case No.2......
# ...

# %%
config = {
        "inflow": 8.,
        "theta_w": 270,
        "sector": [1,],
        "wm": ["Frandsen",],
        "wsm": ["GS", "LS", "EB", "SS",],
        "tim": ["Crespo",],
        "tsm": None,
        "ignore": ["inflow", ],
    }

theta = [270, 222, 312]
sector = [[1], [5], [10], [15]]

Horns = HornsRev1()
for j in theta:
    for k in sector:
        config["theta_w"], config["sector"] = j, k
        Horns.WP2015_Fig_6_comparsion(config, config["theta_w"], sectors=config["sector"],
                    psave=f"20_10_02/3/{j}_{k[0]}_FC", dsave=None, show=False)
# Out:
# ====> calculating Case No.1......
# ...running time of 270+1+Frandsen+GS+Crespo: 0.184 sec
# ====> calculating Case No.2......
# ...running time of 270+1+Frandsen+LS+Crespo: 0.173 sec
# ====> calculating Case No.3......
# ...running time of 270+1+Frandsen+EB+Crespo: 0.185 sec
# ====> calculating Case No.4......
# ...running time of 270+1+Frandsen+SS+Crespo: 0.196 sec
# ====== Picture 20_10_02/3/270_1_FC Save Done !======
#
# ====> calculating Case No.1......
# ...running time of 270+5+Frandsen+GS+Crespo: 0.648 sec
# ====> calculating Case No.2......
# ...running time of 270+5+Frandsen+LS+Crespo: 0.645 sec
# ====> calculating Case No.3......
# ...running time of 270+5+Frandsen+EB+Crespo: 0.7 sec
# ====> calculating Case No.4......
# ...running time of 270+5+Frandsen+SS+Crespo: 0.664 sec
# ====== Picture 20_10_02/3/270_5_FC Save Done !======
#
# ====> calculating Case No.1......
# ...running time of 270+10+Frandsen+GS+Crespo: 1.277 sec
# ====> calculating Case No.2......
# ...
