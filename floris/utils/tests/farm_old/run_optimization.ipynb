# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
root = os.getcwd() + "/.."
# print(root)
sys.path.append(root)
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing as mp

# %%
config = {
        "wt_num": 80.,
        "inflow": 8.,
        "theta_w": None,
        "sector": 5,
        "wm": "Jensen",
        "wsm": "SS",
        "tim": "Frandsen",
        "tsm": None,
        "ignore": ["inflow", ],
    }

# %%
wt_loc = np.array([[3550., 2786.],
       [2935., 1704.],
       [3577., 2346.],
       [4207., 2770.],
       [3101., 2721.],
       [3313., 1879.],
       [2716., 3856.],
       [5020., 2530.],
       [4543., 2152.],
       [4081., 2061.],
       [4198., 1551.],
       [3543., 3379.],
       [5069., 3021.],
       [3841., 3102.],
       [3732., 3752.],
       [4844., 1844.],
       [2720., 3133.],
       [2578., 2239.],
       [3961., 4231.],
       [4390., 3163.]])

# %%
wt_sorted = np.array([18,  6, 14, 11, 19, 16, 13, 12,  0,  3,  4,  7,  2, 17,  8,  9,  5,
                      15,  1, 10], dtype=np.int64)

# %%
transformed_wt_loc = np.array([[3550., 2786.],
       [2935., 1704.],
       [3577., 2346.],
       [4207., 2770.],
       [3101., 2721.],
       [3313., 1879.],
       [2716., 3856.],
       [5020., 2530.],
       [4543., 2152.],
       [4081., 2061.],
       [4198., 1551.],
       [3543., 3379.],
       [5069., 3021.],
       [3841., 3102.],
       [3732., 3752.],
       [4844., 1844.],
       [2720., 3133.],
       [2578., 2239.],
       [3961., 4231.],
       [4390., 3163.]])

# %%
def line(data):
    x = np.array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
                 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5, 22.5, 23.5, 24.5])
    
    fig = plt.figure(dpi=100)
    ax = fig.add_subplot(111)
    ax.plot(x, data)

# %%
deficits = np.load('../output/deficits.npy')

# %%
print(deficits[:, 0, 0])

line(deficits[:, 0, 0])
# Out:
# [0.21963962 0.21963962 0.21963962 0.21963962 0.19702706 0.16796649
#  0.13683663 0.10690494 0.08042799 0.05889983 0.04319135 0.0335563
#  0.02950413 0.02952559 0.03066962 0.02809322 0.02335059 0.02335059
#  0.02335059 0.02335059 0.02335059]

# %%
print(deficits[:, 0, 1])

line(deficits[:, 0, 1])
# Out:
# [0.18339238 0.18339238 0.18339238 0.18339238 0.16451158 0.14024689
#  0.11425441 0.08926236 0.06715492 0.04917956 0.03606346 0.02801849
#  0.02463505 0.02465296 0.0256082  0.02345699 0.01949703 0.01949703
#  0.01949703 0.01949703 0.01949703]

# %%
print(deficits[:, 0, 2])

line(deficits[:, 0, 2])
# Out:
# [0.0993071  0.0993071  0.0993071  0.0993071  0.08908313 0.07594379
#  0.06186884 0.04833563 0.03636443 0.02663077 0.01952839 0.01517203
#  0.01333989 0.0133496  0.01386686 0.01270197 0.01055766 0.01055766
#  0.01055766 0.01055766 0.01055766]

# %%
x = np.array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
                 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5, 22.5, 23.5, 24.5])
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax.plot(x, deficits[:, 0, 0], '-b', x, deficits[:, 0, 1], '--r', x, deficits[:, 0, 2], '.g',  x, deficits[:, 0, 3], '-y')

# %%
x = np.array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
                 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5, 22.5, 23.5, 24.5])
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax.plot(x, deficits[:, 0, 4], '-b', x, deficits[:, 0, 5], '--r', x, deficits[:, 0, 6], '.g',  x, deficits[:, 0, 7], '-y')

# %%
x = np.array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
                 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5, 22.5, 23.5, 24.5])
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax.plot(x, deficits[:, 0, 8], '-b', x, deficits[:, 0, 9], '--r', x, deficits[:, 0, 10], '.g',  x, deficits[:, 0, 11], '-y')

# %%
x = np.array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
                 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5, 22.5, 23.5, 24.5])
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax.plot(x, deficits[:, 0, 12], '-b', x, deficits[:, 0, 13], '--r', x, deficits[:, 0, 14], '.g',  x, deficits[:, 0, 15], '-y')
