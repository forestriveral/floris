# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
root = "/".join(os.getcwd().split('/')[:5])
# package = "/".join(os.getcwd().split('/')[:5] + ['utils'])
# root = os.path.dirname(os.path.dirname(__file__))
sys.path.append(root)
# sys.path.append(package)
import utils.ann as ann

# %%
layers = (3, 20, 1)

ann.net_train(layers, )
# Out:
# Epoch 50 ==> train error: 0.0873 | test error: 0.0866
# Epoch 100 ==> train error: 0.0601 | test error: 0.0597
# Epoch 150 ==> train error: 0.0499 | test error: 0.0498
# Epoch 200 ==> train error: 0.0454 | test error: 0.0454
# Epoch 250 ==> train error: 0.0427 | test error: 0.0427
# Epoch 300 ==> train error: 0.0407 | test error: 0.0407
# Epoch 350 ==> train error: 0.0391 | test error: 0.0391
# Epoch 400 ==> train error: 0.0378 | test error: 0.0377
# Epoch 450 ==> train error: 0.0367 | test error: 0.0366
# Epoch 500 ==> train error: 0.0357 | test error: 0.0356
# error tensor([[ 0.0254],
#         [-0.0299],
#         [ 0.0027],
#         [ 0.0075],
#         [ 0.0019],
#         [ 0.0174],
#         [ 0.0321],
#         [-0.0504],
#         [ 0.0642],
#         [ 0.0523],
#         [-0.0595],
#         [-0.0601],
#         [-0.0346],
#         [ 0.0487],
#         [-0.0334],
#         [ 0.0611],
#         [ 0.0322],
#         [ 0.0367],
#         [-0.0481],
# ...

# %%
layers = (5, 30, 1)

ann.net_train(layers, wm="BP", pshow=True, wsave=True)
# Out:
# Epoch 50 ==> train error: 6.8711 | test error: 6.8410
# Epoch 100 ==> train error: 5.8896 | test error: 6.2363
# Epoch 150 ==> train error: 5.6542 | test error: 5.4745
# Epoch 200 ==> train error: 5.4238 | test error: 5.2141
# Epoch 250 ==> train error: 5.1236 | test error: 5.0763
# Epoch 300 ==> train error: 4.8699 | test error: 5.1351
# Epoch 350 ==> train error: 4.7078 | test error: 5.0180
# Epoch 400 ==> train error: 4.7106 | test error: 4.7248
# Epoch 450 ==> train error: 4.7502 | test error: 4.9266
# Epoch 500 ==> train error: 4.6013 | test error: 4.6580
# error tensor([[ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [-10.6586],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
#         [ -0.6405],
# ...
