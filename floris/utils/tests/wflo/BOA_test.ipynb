# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('/Users/forestriveral/Documents/Projects/WFLO')
import numpy as np
from bayes_opt import BayesianOptimization

import utils.optimizer as uopt
import miscellaneous.BOA_fuqing as boa
import utils.yawed_optimizer as uyopt

# %%
boa.BOA(9)
# Out:
# |   iter    |  target   |    x1     |    x10    |    x11    |    x12    |    x13    |    x14    |    x15    |    x16    |    x17    |    x18    |    x2     |    x3     |    x4     |    x5     |    x6     |    x7     |    x8     |    x9     |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1        |  12.49    | -15.44    |  0.2749   |  9.461    |  0.08048  | -21.91    |  0.04099  |  12.42    |  0.1154   |  22.47    |  0.0452   |  0.1934   | -0.4489   |  0.03786  |  19.41    |  0.1764   | -13.26    |  0.05848  |  28.94    |
# |  2        |  11.95    |  20.05    |  0.1258   |  6.541    |  0.1201   |  5.583    |  0.1246   | -4.089    |  0.2235   |  17.87    |  0.2568   |  0.1921   |  8.911    |  0.2014   | -7.466    |  0.2158   | -28.83    |  0.1456   | -17.89    |
# ...

# %%
uyopt.yawed_case_run(5, 20, 50)
# Out:
# ...
# gen|  eval  |    f_opt    |    f_max    |    f_avg    |    f_min    |    f_std
# ----------------------------------------------------------------------------------
#  0 |   20   | 6.94647E+00 | 6.94647E+00 | 6.55414E+00 | 6.01934E+00 | 2.35770E-01
#  1 |   40   | 6.94729E+00 | 6.94729E+00 | 6.66569E+00 | 6.25846E+00 | 1.59645E-01
#  2 |   60   | 7.12848E+00 | 7.12848E+00 | 6.74777E+00 | 6.51038E+00 | 1.38481E-01
#  3 |   80   | 7.12848E+00 | 7.12848E+00 | 6.81743E+00 | 6.51038E+00 | 1.47435E-01
#  4 |  100   | 7.12848E+00 | 7.12848E+00 | 6.85594E+00 | 6.51038E+00 | 1.47402E-01
#  5 |  120   | 7.17065E+00 | 7.17065E+00 | 6.91417E+00 | 6.51038E+00 | 1.55464E-01
#  6 |  140   | 7.19040E+00 | 7.19040E+00 | 6.97716E+00 | 6.60269E+00 | 1.25215E-01
#  7 |  160   | 7.21486E+00 | 7.21486E+00 | 7.01386E+00 | 6.85121E+00 | 9.38797E-02
#  8 |  180   | 7.21487E+00 | 7.21487E+00 | 7.04658E+00 | 6.91769E+00 | 8.72642E-02
# ...

# %%
uyopt.yawed_case_run(5, 30, 50)
# Out:
# ...
# gen|  eval  |    f_opt    |    f_max    |    f_avg    |    f_min    |    f_std
# ----------------------------------------------------------------------------------
#  0 |   30   | 6.90918E+00 | 6.90918E+00 | 6.55537E+00 | 5.96294E+00 | 2.38303E-01
#  1 |   60   | 7.03548E+00 | 7.03548E+00 | 6.67897E+00 | 6.17089E+00 | 2.19899E-01
#  2 |   90   | 7.05034E+00 | 7.05034E+00 | 6.78014E+00 | 6.33596E+00 | 1.90978E-01
#  3 |  120   | 7.05034E+00 | 7.05034E+00 | 6.86046E+00 | 6.44174E+00 | 1.47601E-01
#  4 |  150   | 7.14177E+00 | 7.14177E+00 | 6.91482E+00 | 6.55017E+00 | 1.32455E-01
#  5 |  180   | 7.14516E+00 | 7.14516E+00 | 6.94630E+00 | 6.59207E+00 | 1.22389E-01
#  6 |  210   | 7.14516E+00 | 7.14516E+00 | 6.99514E+00 | 6.80720E+00 | 7.41818E-02
#  7 |  240   | 7.14516E+00 | 7.14516E+00 | 7.01952E+00 | 6.90354E+00 | 6.69898E-02
#  8 |  270   | 7.14516E+00 | 7.14516E+00 | 7.03642E+00 | 6.91389E+00 | 6.20156E-02
# ...

# %%
uyopt.yawed_case_run(9, 30, 70)
# Out:
# ...
# gen|  eval  |    f_opt    |    f_max    |    f_avg    |    f_min    |    f_std
# ----------------------------------------------------------------------------------
#  0 |   30   | 1.25439E+01 | 1.25439E+01 | 1.20850E+01 | 1.14881E+01 | 2.59133E-01
#  1 |   60   | 1.25439E+01 | 1.25439E+01 | 1.21911E+01 | 1.17268E+01 | 2.17789E-01
#  2 |   90   | 1.25641E+01 | 1.25641E+01 | 1.22820E+01 | 1.18482E+01 | 1.77987E-01
#  3 |  120   | 1.27916E+01 | 1.27916E+01 | 1.24059E+01 | 1.19619E+01 | 2.14258E-01
#  4 |  150   | 1.27982E+01 | 1.27982E+01 | 1.24906E+01 | 1.19619E+01 | 2.04183E-01
#  5 |  180   | 1.27982E+01 | 1.27982E+01 | 1.25344E+01 | 1.19619E+01 | 1.98162E-01
#  6 |  210   | 1.28714E+01 | 1.28714E+01 | 1.25806E+01 | 1.20753E+01 | 1.88466E-01
#  7 |  240   | 1.28714E+01 | 1.28714E+01 | 1.26118E+01 | 1.20753E+01 | 1.62814E-01
#  8 |  270   | 1.28714E+01 | 1.28714E+01 | 1.26662E+01 | 1.24451E+01 | 1.17907E-01
# ...

# %%
uyopt.yawed_case_run(25, 30, 70)
# Out:
# ...
# gen|  eval  |    f_opt    |    f_max    |    f_avg    |    f_min    |    f_std
# ----------------------------------------------------------------------------------
#  0 |   30   | 3.36813E+01 | 3.36813E+01 | 3.28410E+01 | 3.18983E+01 | 4.36763E-01
#  1 |   60   | 3.41991E+01 | 3.41991E+01 | 3.31580E+01 | 3.21449E+01 | 4.52899E-01
#  2 |   90   | 3.42776E+01 | 3.42776E+01 | 3.33271E+01 | 3.22215E+01 | 4.82845E-01
#  3 |  120   | 3.42776E+01 | 3.42776E+01 | 3.35153E+01 | 3.25799E+01 | 4.43632E-01
#  4 |  150   | 3.45365E+01 | 3.45365E+01 | 3.37535E+01 | 3.27511E+01 | 4.25279E-01
#  5 |  180   | 3.45365E+01 | 3.45365E+01 | 3.38658E+01 | 3.32145E+01 | 3.60400E-01
#  6 |  210   | 3.45365E+01 | 3.45365E+01 | 3.40009E+01 | 3.32145E+01 | 3.63443E-01
#  7 |  240   | 3.46900E+01 | 3.46900E+01 | 3.40716E+01 | 3.32145E+01 | 3.53934E-01
#  8 |  270   | 3.47785E+01 | 3.47785E+01 | 3.41413E+01 | 3.32145E+01 | 3.59627E-01
# ...

# %%
vel = 8.0

a = 0.0001654 * vel**4 - 0.007023 * vel**3 + 0.08969 * vel**2 - 0.2108 * vel**1 + 0.3212

a
# Out:
# 1.4566624000000006
