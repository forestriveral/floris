# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
root = "/".join(os.getcwd().split('/')[:5])
package = "/".join(os.getcwd().split('/')[:5] + ['utils'])
# root = os.path.dirname(os.path.dirname(__file__))
sys.path.append(root)
sys.path.append(package)
import utils.optimizer as uopt
import utils.cost as cost

# %%
config = {
        "pop": 30,
        "maxg": 5,
        
        "param": "horns",
        "num": 30,
        "sector": 5,
        "vbins": 21,
        "Iam": 0.077,
        "winds": "horns",
        "watdepth": 10.,
        "cost": "LCOE",
        # "cost": "mosetti",
#         "cost": "maxpower",
        "wm": "Jensen",
#         "wm": "Bastankhah",
        "wsm": "SS",
#         "tim": "Frandsen",
        "tim": None,
        "tsm": None,
    }

# %%
uopt.EAOptimizer(config).solution()
# Out:
# ===> One generation done! Elapsed time: 84.88440322875977
# ===> One generation done! Elapsed time: 69.62700510025024
# ===> One generation done! Elapsed time: 65.81148171424866
# ===> One generation done! Elapsed time: 56.37587022781372
# ===> One generation done! Elapsed time: 59.929603815078735
# Evaluation times：150
# Elapsed time 5.610728979110718 m
# No feasible solution

# %%
config = {
        "pop": 30,
        "maxg": 20,
        
        "param": "horns",
        "num": 5,
        "sector": 5,
        "vbins": 21,
        "Iam": 0.077,
        "winds": "horns",
        "watdepth": 10.,
#         "cost": "LCOE",
#         "cost": "mosetti",
        "cost": "test",
        "wm": "Jensen",
        # "wm": "Bastankhah",
        "wsm": "SS",
        # "tim": "Frandsen",
        "tim": None,
        "tsm": None,
    }

uopt.EAOptimizer(config).solution()
# Out:
# ===> One generation done! Elapsed time: 4.405105352401733
# ...
# gen|  eval  |    f_opt    |    f_max    |    f_avg    |    f_min    |    f_std
# ----------------------------------------------------------------------------------
#  0 |   30   | 1.52457E-01 | 1.53189E-01 | 1.52661E-01 | 1.52457E-01 | 1.56672E-04
# ===> One generation done! Elapsed time: 6.140306711196899
#  1 |   60   | 1.52364E-01 | 1.52795E-01 | 1.52536E-01 | 1.52364E-01 | 1.00098E-04
# ===> One generation done! Elapsed time: 9.195708990097046
#  2 |   90   | 1.52329E-01 | 1.52982E-01 | 1.52477E-01 | 1.52329E-01 | 1.19191E-04
# ===> One generation done! Elapsed time: 6.58485746383667
#  3 |  120   | 1.52329E-01 | 1.52606E-01 | 1.52442E-01 | 1.52329E-01 | 6.32251E-05
# ===> One generation done! Elapsed time: 7.505151748657227
#  4 |  150   | 1.52329E-01 | 1.52606E-01 | 1.52429E-01 | 1.52329E-01 | 6.42624E-05
# ===> One generation done! Elapsed time: 8.526068687438965
# ...
